# %%
'''
 1.In Nigeria, one of the booming tech spaces is fintech. How do you think computer vision can help improve payment?
Biometrics
QR-Code
Swipe and pay.
answer: 
Biometrics:
Computer vision-based biometric systems, such as facial recognition and fingerprint scanning, can serve as secure, user-friendly authentication methods. This minimizes fraud by ensuring that only the verified user can authorize transactions, which is particularly critical in a market like Nigeria’s where digital payments are rapidly growing.

QR-Code Integration:
By using advanced computer vision algorithms to improve QR-code detection and decoding, payment systems can become more reliable and faster, even under challenging conditions such as poor lighting or low-resolution images. This ensures seamless, error-free transactions that can boost consumer confidence in digital payments.

Swipe and Pay:
Incorporating gesture recognition through computer vision can enable innovative “swipe and pay” methods where visual cues—like a specific hand gesture—trigger secure payment processes. This not only simplifies user interactions but also provides an additional layer of security by combining visual authentication with traditional payment methods.

2.In Nigeria, we have healthtech startups combating the free access to healthcare. How do you think computer vision can help these startups better reach more people to have access to quality and good healthcare.
answer:
Automated Diagnostic Imaging:
Computer vision can process and analyze medical images (e.g., X-rays, CT scans, and MRIs) to detect anomalies and patterns that might indicate health issues. This rapid, automated diagnostic capability helps healthcare startups reduce wait times, improve diagnostic accuracy, and optimize the use of scarce medical resources.

Remote Patient Monitoring:
Integrating computer vision into telemedicine applications enables real-time monitoring of patient conditions using smartphone cameras or other imaging devices. For example, it can help detect changes in a patient’s physical appearance that correlate with health conditions, thus facilitating early intervention and continuous care even in remote or underserved areas.

Smart Wearables and AR Solutions:
Computer vision-powered wearables can track health indicators such as skin conditions or facial expressions related to pain and stress, while augmented reality applications can provide interactive health education and guidance. These technologies empower patients to better manage their conditions and adhere to treatment plans, ultimately improving the overall quality of healthcare.

'''

# %%
import numpy as np
import cv2 as cv 
import matplotlib.pyplot as plt

# %%
img= cv.imread(r"C:\Users\Benwari Ezekiel\Downloads\Corrupted Student Picture.png")
plt.imshow(img)

# %%
img2 =plt.imshow(img) 
grayscale = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(grayscale, cmap='gray')

# %%
rgb_color = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(rgb_color)

# %%
alpha = 1
beta = 2

adjusted = cv.convertScaleAbs(img, alpha=alpha, beta=beta)
plt.imshow(adjusted)
